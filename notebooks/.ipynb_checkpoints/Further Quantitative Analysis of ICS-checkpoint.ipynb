# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.style
matplotlib.style.use("seaborn")
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
import matplotlib.cm as cm
from sklearn.preprocessing import PowerTransformer, QuantileTransformer

import seaborn as sns
sns.color_palette("hls", 17)
import scipy.stats as st
import math
from sklearn.utils import resample

from pingouin import rcorr
import pingouin as pg

# %%
import sys
import os
sys.path.append(os.path.join(".."))

from module.trend_analysis_functions import *
from module.topic_model_plus_class import Topic_Model_plus

# %%
incident_file = os.path.join(os.path.dirname(os.getcwd()),'data','ICS_data','ICS_predictive_summaryreps_full.csv')
incident_summary_df = pd.read_csv(incident_file)
incident_summary_df = incident_summary_df.drop("Unnamed: 0", axis=1)
incident_summary_df = incident_summary_df.loc[incident_summary_df["START_YEAR"]>=2006].reset_index(drop=True)
# Out:
# C:\Users\srandrad\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,13,18,19,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Hazard Metrics

# %%
document_id_col = "INCIDENT_ID"
extra_cols = ["CY","DISCOVERY_DATE", "START_YEAR", "REPORT_DOY", "DISCOVERY_DOY",
              "TOTAL_PERSONNEL", "TOTAL_AERIAL", "PCT_CONTAINED_COMPLETED", "Unique_IDs",
              "ACRES",  "WF_FSR", "INJURIES", "FATALITIES", "EST_IM_COST_TO_DATE", "STR_DAMAGED",
              "STR_DESTROYED", "NEW_ACRES", "POO_STATE", "POO_LATITUDE", "POO_LONGITUDE", "WEATHER_CONCERNS_NARR",
              "INC_MGMT_ORG_ABBREV", "EVACUATION_IN_PROGRESS", "Incident_region", "Traffic","Command_Transitions",
              "Evacuations", "Inaccurate_Mapping", "Aerial_Grounding", "Resource_Issues", "Injuries", "Cultural_Resources",
              "Livestock", "Law_Violations", "Military_Base", "Infrastructure",
              "Extreme_Weather", "Ecological", "Hazardous_Terrain", "Floods", "Dry_Weather", "Severity", "NUM_REPORTS", 
              "DAYS_BURING"]

list_of_attributes = ["Combined_Text", "Total_Incident_Text"]
file = os.path.join(os.path.dirname(os.getcwd()),'data','ICS_data','ICS_predictive_model_sitreps.csv')
ICS = Topic_Model_plus(document_id_col=document_id_col, extra_cols=extra_cols, list_of_attributes=list_of_attributes, combine_cols=False)
ICS.extract_preprocessed_data(file)
# Out:
# C:\Users\srandrad\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3242: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
preprocessed_df = ICS.data_df
hazard_file = os.path.join(os.path.dirname(os.getcwd()),'results','hazard_interpretation_v2.xlsx')

# %%
time_of_occurence_days, time_of_occurence_pct_contained, frequency, fires, frequency_fires, categories, hazards, years, ids = calc_metrics(hazard_file, preprocessed_df, rm_outliers=True, target="Combined_Text", unique_ids_col="Unique_IDs")
# Out:
# C:\Users\srandrad\Anaconda3\lib\site-packages\openpyxl\compat\numbers.py:41: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   numpy.float,
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [05:13<00:00, 34.86s/it]

# %%
table_data = create_primary_results_table(time_of_occurence_days, time_of_occurence_pct_contained, frequency, frequency_fires, preprocessed_df, categories, hazards, years, interval=False)
severity_total, severity_table = calc_severity(fires, incident_summary_df)
pd.DataFrame(table_data)
# Out:
#              Hazard Category          Hazard Name       OTTO days  \
# 0                    Mission              Traffic   9.831+-10.889
# 1                    Mission  Command Transitions   15.95+-21.251
# 2                    Mission          Evacuations   11.109+-12.66
# 3                    Mission   Inaccurate Mapping    6.201+-6.422
# 4                    Mission     Aerial Grounding  16.086+-17.537
# 5                    Mission      Resource Issues  10.546+-12.107
# 6                    Mission             Injuries   9.901+-10.425
# 7   Wildland Urban Interface   Cultural Resources    8.534+-8.306
# 8   Wildland Urban Interface            Livestock    8.421+-9.204
# 9   Wildland Urban Interface       Law Violations    2.128+-6.797
# 10  Wildland Urban Interface        Military Base    11.112+-16.8
# 11  Wildland Urban Interface       Infrastructure  10.943+-12.062
# 12             Environmental      Extreme Weather     5.701+-6.95
# ...

# %%
def hazard_histogram(time_of_occurence_pct_contained):
    hist_data = {hazard:[d for year in time_of_occurence_pct_contained[hazard] for d in time_of_occurence_pct_contained[hazard][year]] for hazard in time_of_occurence_pct_contained}
    for hazard in hist_data:
        plt.hist(hist_data[hazard], 20, density=True)
        plt.xlabel('OTTO %')
        plt.ylabel('Probability')
        plt.title(hazard+ 'Histogram of OTTO')
        plt.grid(True)
        plt.show()
def stacked_hazard_histogram(data, label, bins=10, xmax_val=100, xmin_val=0, ymax_val=0.3, ymin_val=0):
    hist_data = {hazard:[d for year in data[hazard] for d in data[hazard][year]] for hazard in data}
    colors = cm.tab20(np.linspace(0, 1, len(data)))
    plt.xlabel(label)
    plt.xlim(xmin_val, xmax_val)
    plt.ylim(ymin_val, ymax_val)
    plt.ylabel('Probability')
    plt.title('Histograms of '+label)
    plt.grid(True)
    i=0
    for hazard in hist_data:
        plt.hist(hist_data[hazard], 20, density=True, facecolor=colors[i], label=hazard)
        i+=1
    plt.legend()
    plt.show()

# %%
stacked_hazard_histogram(time_of_occurence_pct_contained, label="OTTO %", ymax_val=0.15, ymin_val=0)
stacked_hazard_histogram(severity_total, label="Severity", xmax_val=500, xmin_val=0, ymax_val=0.1,)

# %% [markdown]
# # Hazard predictor analysis

# %% [markdown]
# ### Predictors
# - *TF-IDF of reports
# - #of reports so far - manual
# - #personnel - TOTAL_PERSONNEL
# - #aerial assets - TOTAL_AERIAL
# - Acres burned so far - ACRES
# - % containment - PCT_CONTAINED_COMPLETED
# - Days burning - REPORT_DOY - DISCOVERY_DOY
# - *Weather - WEATHER_CONCERNS_NARR
# - *Region - POO_STATE/ POO_LATITUDE/POO_LONGITUDE - Categorical
# - Spread Rate - WF_FSR
# - Injuries, Fatalities - INJURIES, FATALITIES
# - Cost -- to date and total predicted -- EST_IM_COST_TO_DATE
# - Structures damaged/destroyed -- possibly divide into residential/commercial? - STR_DAMAGED/STR_DESTROYED
# - growth - NEW_ACRES
# - *Command type - IMT_MGMT_ORG_DESC/INC_MGMT_ORG_ABBREV - Categorical
# - *evacuation in progress - EVACUATION_IN_PROGRESS - Categorical

# %%
def diff_chi_squared(expected, observed):
    diffs_0 = []
    diffs_1 = []
    for i in range(len(expected)):
        diffs_0.append(observed.iloc[i][0] - expected.iloc[i][0])
        diffs_1.append(observed.iloc[i][1] - expected.iloc[i][1])
    diffs_df = pd.DataFrame({'0':diffs_0, '1':diffs_1}, index = expected.index)
    display(diffs_df)
    
def get_means(group, group_val, target, df):
    group_val_df = df.loc[df[group]==group_val].reset_index(drop=True)
    val_mean = np.mean(group_val_df[target])
    other_val_df = df.loc[df[group]!=group_val].reset_index(drop=True)
    other_val_mean = np.mean(other_val_df[target])
    return val_mean, other_val_mean

# %%
predictor_cols = ['NUM_REPORTS', 'TOTAL_PERSONNEL', 'TOTAL_AERIAL', 'ACRES', 'PCT_CONTAINED_COMPLETED',
                 'DAYS_BURING', 'WF_FSR', 'INJURIES', 'FATALITIES', 'EST_IM_COST_TO_DATE', 'STR_DAMAGED',
                 'STR_DESTROYED', 'NEW_ACRES']

# %%
predictor_data = {predictor:[] for predictor in predictor_cols}
predictor_pvals = {predictor:[] for predictor in predictor_cols}
for hazard in hazards:
    for predictor in predictor_cols:
        preprocessed_df[predictor] = preprocessed_df[predictor].astype(float)
        aov = pg.anova(dv=predictor, between=hazard.replace(" ", "_"), data=preprocessed_df,
               detailed=True).round(3)
        hazard_mean, no_hazard_mean = get_means(hazard.replace(" ", "_"), 1, predictor, preprocessed_df)
        predictor_data[predictor].append((aov.iloc[0]['p-unc'],aov.iloc[0]['F'], hazard_mean, no_hazard_mean))
        predictor_pvals[predictor].append(aov.iloc[0]['p-unc'])
predictor_pvals_df = pd.DataFrame(predictor_pvals, index=hazards)
predictor_df = pd.DataFrame(predictor_data, index=hazards)
predictor_df
# Out:
#                                                            NUM_REPORTS  \
# Traffic              (0.0, 4405.043, 31.498463207376606, 6.13150882...
# Command Transitions  (0.0, 4361.745, 28.73740902474527, 4.237275291...
# Evacuations          (0.0, 5195.136, 33.33995084136888, 5.752421392...
# Inaccurate Mapping   (0.0, 4857.257, 39.17259383311989, 8.631035893...
# Aerial Grounding     (0.0, 10791.823, 72.86411149825784, 9.91840376...
# Resource Issues      (0.0, 5411.529, 34.944896551724135, 6.23597763...
# Injuries             (0.0, 5643.01, 39.25673137132123, 7.6565513500...
# Cultural Resources   (0.0, 5892.29, 59.466064453125, 11.15933642933...
# Livestock            (0.0, 6508.943, 54.512306289881494, 10.1323627...
# Law Violations       (0.04, 4.216, 10.850162866449512, 15.652692028...
# Military Base        (0.045, 4.034, 19.524027459954233, 15.58061284...
# Infrastructure       (0.0, 6829.27, 60.69963453631795, 10.683581343...
# ...

# %% [markdown]
# ## Predictor: Command Type
# since this is a categorical variable, a chi-squared test will be used.
# null hypothesis: Hazards occur at the same rate accross command types
# alternate hypothesis: hazards occur at different rates for different command types

# %%
p_vals = []
chi_vals = []
for hazard in hazards:
    expected, observed, stats = pg.chi2_independence(preprocessed_df, x='INC_MGMT_ORG_ABBREV', y=hazard.replace(" ", "_"))
    print(hazard)
    #diff_chi_squared(expected, observed)
    pval = stats.iloc[1]['pval'].round(3)
    p_vals.append(stats.iloc[0]['pval'].round(3))
    chi_vals.append(stats.iloc[0]['chi2'].round(3))
chi_squared_df = pd.DataFrame({"chi-squared pval": p_vals, "chi-squared statistic": chi_vals}, index = hazards)
predictor_pvals_df['Command Type'] = p_vals
chi_squared_df
# Out:
# Traffic
# Command Transitions
# Evacuations
# Inaccurate Mapping
# Aerial Grounding
# Resource Issues
# Injuries
# Cultural Resources
# Livestock
# Law Violations
# Military Base
# Infrastructure
# C:\Users\srandrad\AppData\Roaming\Python\Python38\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn('Low count on {} frequencies.'.format(name))
# C:\Users\srandrad\AppData\Roaming\Python\Python38\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn('Low count on {} frequencies.'.format(name))
# C:\Users\srandrad\AppData\Roaming\Python\Python38\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn('Low count on {} frequencies.'.format(name))
# C:\Users\srandrad\AppData\Roaming\Python\Python38\site-packages\pingouin\contingency.py:151: UserWarning: Low count on expected frequencies.
# ...

# %% [markdown]
# ## Predictor: Evacuation
# since this is a categorical variable, a chi-squared test will be used.
# null hypothesis: Hazards occur at the same rate regardless of evacuations
# alternate hypothesis: hazards occur more or less frequently depending on evacuation

# %%
p_vals = []
chi_vals = []
for hazard in hazards:
    expected, observed, stats = pg.chi2_independence(preprocessed_df, x='EVACUATION_IN_PROGRESS', y=hazard.replace(" ", "_"))
    print(hazard)
    diff_chi_squared(expected, observed)
    pval = stats.iloc[1]['pval'].round(3)
    p_vals.append(stats.iloc[0]['pval'].round(3))
    chi_vals.append(stats.iloc[0]['chi2'].round(3))
chi_squared_df = pd.DataFrame({"chi-squared pval": p_vals, "chi-squared statistic": chi_vals}, index = hazards)
predictor_pvals_df['Evacuation'] = p_vals
chi_squared_df
# Out:
# Traffic
#                                   0            1
# EVACUATION_IN_PROGRESS
# False                   1087.257238 -1087.257238
# True                   -1087.257238  1087.257238
# Command Transitions
#                                  0           1
# EVACUATION_IN_PROGRESS
# False                   879.298485 -879.298485
# True                   -879.298485  879.298485
# Evacuations
#                                  0           1
# EVACUATION_IN_PROGRESS
# False                   1634.12227 -1634.12227
# True                   -1634.12227  1634.12227
# Inaccurate Mapping
#                                  0           1
# EVACUATION_IN_PROGRESS
# False                   236.406961 -236.406961
# True                   -236.406961  236.406961
# Aerial Grounding
#                                  0           1
# EVACUATION_IN_PROGRESS
# False                   253.101841 -253.101841
# True                   -253.101841  253.101841
# Resource Issues
# ...

# %% [markdown]
# ## Chi-Squared test
#
# For each hazard, is there a significant different in hazard frequency across regions
# - null hypothesis: hazards occur at the same frequency across regions (p>0.05)
# - alternate hypothesis: hazards occur at different frequencies across regions (p<0.05)
# target = hazard occurs or not
# X = region

# %%
p_vals = []
chi_vals = []
indices = []
for hazard in hazards:
    expected, observed, stats = pg.chi2_independence(preprocessed_df, x='Incident_region', y=hazard.replace(" ", "_"))
    indices.append(hazard)
    print(hazard)
    diff_chi_squared(expected, observed)
    pval = stats.iloc[1]['pval'].round(3)
    p_vals.append((stats.iloc[0]['pval'].round(3)))
    chi_vals.append((stats.iloc[0]['chi2'].round(3)))
# Out:
# Traffic
#                            0            1
# Incident_region
# AICC              366.651241  -366.651241
# CA              -1967.722617  1967.722617
# EACC              271.236114  -271.236114
# GBCC                4.644747    -4.644747
# HICC               -4.941682     4.941682
# NRCC              -67.427576    67.427576
# NWCC             -473.985319   473.985319
# RMCC              232.396996  -232.396996
# SACC             1375.395711 -1375.395711
# SWCC              263.752385  -263.752385
# Command Transitions
# C:\Users\srandrad\AppData\Roaming\Python\Python38\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn('Low count on {} frequencies.'.format(name))
# C:\Users\srandrad\Anaconda3\lib\site-packages\scipy\stats\stats.py:6716: RuntimeWarning: divide by zero encountered in power
#   terms = f_obs * ((f_obs / f_exp)**lambda_ - 1)
# ...

# %%
chi_squared_df = pd.DataFrame({"chi-squared pval": p_vals, "chi-squared statistic": chi_vals}, index = indices)
chi_squared_df
# Out:
#                      chi-squared pval  chi-squared statistic
# Traffic                           0.0               3352.055
# Command Transitions               0.0               5008.499
# Evacuations                       0.0               3184.354
# Inaccurate Mapping                0.0               1338.343
# Aerial Grounding                  0.0               1253.830
# Resource Issues                   0.0               4577.359
# Injuries                          0.0               2556.643
# Cultural Resources                0.0               1895.709
# Livestock                         0.0               2297.198
# Law Violations                    0.0                494.795
# Military Base                     0.0                453.190
# Infrastructure                    0.0               1888.864
# Extreme Weather                   0.0               2294.267
# Ecological                        0.0                685.776
# ...

# %%
predictor_pvals_df['Region'] = p_vals

# %%
hazard_occurrence_predictors = predictor_pvals_df.drop(['INJURIES', 'FATALITIES', 'STR_DAMAGED', 'STR_DESTROYED', 'PCT_CONTAINED_COMPLETED'], axis=1)
sn.heatmap(hazard_occurrence_predictors, annot=True)
plt.title("P-values for differences in predictors \n between hazard and non-hazard reports")
plt.show()

# %% [markdown]
# The chi-squared test confirms region is a good predictor for hazard occurrence. Specifically, it tells us there is a statistically significant difference in hazard occurrence accross regions

# %% [markdown]
# # Severity Predictor Analysis
# Severity = injuries + fatalities + structures damaged + structures destroyed
# NOTE: Looking at final incident severity for output -> summary report
# input -> incident report
# preditors:
# - hazard occurence : categorical
# - region: categorical
# - acres burned : continuous
# - personnel : continuous
# - aerial assets : continuous
# - spread rate : continuous
# - evacuations : categorical
# - days burning : continuous
# - percent contained : continuous
# - injuries so far : continuous
# - fatalities so far : continuous
# - structures damaged so far : continuous
# - structures destroyed so far : continuous
# - cost so far : continuous
#
# set up for each component of severity:
# ANOCOVA
#
# IV: hazard occurrence, evacuations, region
#
# covariates: acres burned, personnel, aerial assets, spread rate, evacuations, days burning, percent contained, injuries so far,
# fatalities so far, structures damaged so far, structures destroyed so far, cost
#
# DV: severity component

# %%
dvs = ["Severity",'STR_DESTROYED_TOTAL','STR_DAMAGED_TOTAL','INJURIES_TOTAL','FATALITIES']
dv_labels = {"Severity": "Total Severity",
             'STR_DESTROYED_TOTAL': "Structures Destroyed",
             'STR_DAMAGED_TOTAL': "Structures Damaged",
             'FATALITIES': 'Fatalities',
             'INJURIES_TOTAL': "Injuries"}
num_bins_dict = {"Severity": 100,
             'STR_DESTROYED_TOTAL': 100,
             'STR_DAMAGED_TOTAL': 50,
             'FATALITIES': 9,
             'INJURIES_TOTAL':35}
colors = cm.coolwarm(np.linspace(0, 1, len(dvs)+1))
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
plt.yscale('log')
plt.xscale('symlog')
for dv in dvs:
    plot_data = [i for i in incident_summary_df[dv]]
    num_bins =  num_bins_dict[dv]
    hist, bins = np.histogram(plot_data, bins=num_bins)
    logbins = np.logspace(0,np.log10(bins[-1]),len(bins))
    plt.hist(plot_data, bins=num_bins, label=dv_labels[dv], color=colors[dvs.index(dv)], histtype='stepfilled', log=True)
plt.yscale('log')
plt.xscale('symlog')
plt.legend(fontsize=21)
for label in ax.get_yticklabels() + ax.get_xticklabels():
    label.set_fontsize(24)
plt.title("Histograms of Severity Metric Values", fontsize=24)
plt.ylabel("Number of Incidents", fontsize=24)
plt.xlabel("Metric Value", fontsize=24)
plt.savefig('severity_hist.pdf',bbox_inches="tight") 
plt.show()

# %%
num_means = 1000
means = []
for i in range(num_means):
    boot = resample(incident_summary_df["Severity"], replace=True, n_samples=len(incident_summary_df["Severity"]), random_state=i)
    means.append(np.mean(boot))
sns.histplot(means, bins = 50, kde = True)
plt.title("Bootstrap Transform")

plt.show()

# %%
st.normaltest(means)
# Out:
# NormaltestResult(statistic=24.636286705521325, pvalue=4.469905221709073e-06)

# %%
#prepare data: add the dv summary report columns to the situation report df
injuries = []
fatalities = []
str_dam = []
str_destroy = []
for i in range(len(preprocessed_df)):
    incident_id = preprocessed_df.iloc[i]["INCIDENT_ID"]
    summary_df = incident_summary_df.loc[incident_summary_df["INCIDENT_ID"] == incident_id].reset_index(drop=True)
    injuries.append(summary_df.iloc[0]['INJURIES_TOTAL'])
    fatalities.append(summary_df.iloc[0]['FATALITIES'])
    str_dam.append(summary_df.iloc[0]['STR_DAMAGED_TOTAL'])
    str_destroy.append(summary_df.iloc[0]['STR_DESTROYED_TOTAL'])
incident_df = preprocessed_df
incident_df['Total_Injuries'] = injuries
incident_df['Total_Fatalities'] = fatalities
incident_df['Total_Str_Damage'] = str_dam
incident_df['Total_Str_Destroyed'] = str_destroy
incident_df = incident_df.drop("Unnamed: 0", axis=1)

# %%
ivs =  hazards + ['Incident_region', 'EVACUATION_IN_PROGRESS'] 
covars = ['TOTAL_PERSONNEL', 'TOTAL_AERIAL', 'ACRES', 'PCT_CONTAINED_COMPLETED',
                 'DAYS_BURING', 'WF_FSR', 'INJURIES', 'FATALITIES', 'EST_IM_COST_TO_DATE', 'STR_DAMAGED',
                 'STR_DESTROYED']
dvs = ['Total_Injuries', 'Total_Fatalities', 'Total_Str_Damage','Total_Str_Destroyed', "Severity"]
severity_dfs = {dv:pd.DataFrame() for dv in dvs}

# %%
ancova_data = {}

for dv in dvs:
    data = {}
    for covar in covars:
        data[covar+" pval"] = []
        data[covar+" f"] = []
    for hazard in hazards:
        ancova_df = pg.ancova(data=incident_df, dv=dv, covar=covars, between=hazard.replace(" ", "_")).round(3)
        for covar in covars:
            data[covar+" pval"].append(ancova_df.loc[ancova_df['Source']==covar].reset_index(drop=True).iloc[0]['p-unc'])
            data[covar+" f"].append(ancova_df.loc[ancova_df['Source']==covar].reset_index(drop=True).iloc[0]['F'])
    dv_df = pd.DataFrame(data, index=hazards)
    print(dv)
    display(dv_df)
    ancova_data[dv] = dv_df
    severity_dfs[dv] = dv_df
# Out:
# C:\Users\srandrad\Anaconda3\lib\site-packages\patsy\constraint.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Mapping
# Total_Injuries
#                      TOTAL_PERSONNEL pval  TOTAL_PERSONNEL f  \
# Traffic                               0.0           4763.976
# Command Transitions                   0.0           5092.832
# Evacuations                           0.0           4495.987
# Inaccurate Mapping                    0.0           5270.326
# Aerial Grounding                      0.0           5128.442
# Resource Issues                       0.0           4673.311
# Injuries                              0.0           4464.459
# Cultural Resources                    0.0           5174.426
# Livestock                             0.0           5221.605
# Law Violations                        0.0           5261.802
# ...

# %% [markdown]
# ANCOVA looks at the difference between the ivs in the dv when controlling for the covariate. Results that are not significant indicate the covariate is responsible for the relationship between the ivs and dvs.
#
# For Injuries: Acres, % contained, spread rate, injuries so far
#
# For Fatalities: % contained, days burning, spread rate, injuries, cost, str damaged
#
# for Structures damaged: % contained, injuries, fatalities
#
# For Structures destroyed: Acres, percent contained, days burning, injuries
#
# predictors to include: Acres burned, pct containment completed, days burning, spread rate, injuries, fatalaties, cost, str damaged, str destroyed

# %%
anova_data = {}
for dv in dvs:
    data = {}
    for iv in [ 'EVACUATION_IN_PROGRESS', 'Incident_region']:
        data[iv+" pval"] = []
        data[iv+" f"] = []
    for hazard in hazards:
        #print(hazard)
        for iv in [ 'EVACUATION_IN_PROGRESS', 'Incident_region']:#'Incident_region', 'EVACUATION_IN_PROGRESS'] :
            anova_df = pg.anova(data=incident_df, dv=dv, between=[hazard.replace(" ", "_")]+[iv]).round(3)
            data[iv+' pval'].append(anova_df.loc[anova_df['Source']== hazard.replace(" ", "_")+" * "+iv].reset_index(drop=True).iloc[0]['p-unc']) 
            data[iv+' f'].append(anova_df.loc[anova_df['Source']== hazard.replace(" ", "_")+" * "+iv].reset_index(drop=True).iloc[0]['F'])
    dv_df = pd.DataFrame(data, index=hazards)
    severity_dfs[dv] = pd.concat([severity_dfs[dv], dv_df], axis=1)
    print(dv)
    display(dv_df)
    anova_data[dv] = dv_df
# Out:
# C:\Users\srandrad\Anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\srandrad\Anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\srandrad\Anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\srandrad\Anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 8
# ...

# %%
for dv in severity_dfs:
    cols = [col for col in  severity_dfs[dv].columns if "pval" in col]
    pval_df = severity_dfs[dv][cols]
    pval_df.columns = ["Total Personnel", "Total Aerial", "Acres", "% Containment", "Days Burning", "Fire Spread Rate", "Injuries", "Fatalities",
      "Estimated Cost", "Str Damaged", "Str Destroyed", "Evacuation Order", "Region"]
    pval_df = pval_df.drop(["Injuries", "Fatalities", "Str Damaged", "Str Destroyed"], axis=1)
    sn.heatmap(pval_df, annot=True)
    plt.title("P-values for differences in "+ dv+" \n accross predictors")
    plt.show()

# %% [markdown]
# ## Correlations:
# for each incident with a hazard, is there a statistically significant correlation between the predictor/feature and severity?

# %%
covars = ['TOTAL_PERSONNEL', 'TOTAL_AERIAL', 'ACRES', 'PCT_CONTAINED_COMPLETED',
                 'DAYS_BURING', 'WF_FSR', 'INJURIES', 'FATALITIES', 'EST_IM_COST_TO_DATE', 'STR_DAMAGED',
                 'STR_DESTROYED']
dv = "Severity"

# %%
corr_data = {covar: [] for covar in covars}
annotation_data = {covar: [] for covar in covars}

for hazard in hazards:
    hazard_df = incident_df.loc[incident_df[hazard.replace(" ", "_")]==1].reset_index(drop=True) 
    for covar in covars:
        x = hazard_df[dv]
        y = hazard_df[covar]
        corr = pg.corr(x, y).round(2)
        r = corr.iloc[0]['r']; p_val = corr.iloc[0]['p-val']
        corr_data[covar].append(r)
        notation = ""
        if p_val < 0.05:
            notation = "*"
        if p_val < 0.01:
            notation = "**"
        if p_val < 0.001:
            notation = "***"
        annotation_data[covar].append(str(r)+notation)

corr_df = pd.DataFrame(corr_data, index=hazards)
annotation_df = pd.DataFrame(annotation_data, index=hazards)
fig, (cax, ax) = plt.subplots(nrows=2, figsize=(8,8.025),  gridspec_kw={"height_ratios":[0.025, 1]})

# Draw heatmap
sn.heatmap(corr_df, annot=annotation_df,  fmt="s", annot_kws={'fontsize':12},# cbar_kws={"orientation": "horizontal"}, 
           vmin=-1, vmax=1, center= 0, cbar=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tick_params(labelsize=16)
plt.xlabel("Feature", fontsize=16)
plt.ylabel("Hazard", fontsize=16)

# colorbar
cbar = fig.colorbar(ax.get_children()[0], cax=cax, orientation="horizontal")
cbar.ax.tick_params(labelsize=16) 
plt.show()
